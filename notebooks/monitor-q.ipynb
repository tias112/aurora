# %%
from aurora.kiruna.mag_client import MagWatcher
from aurora.kiruna.k_calculator import KIndexCalculator
from aurora.kiruna.kindex_calc import get_probability
from aurora.client.telegram_bot import telegram_bot_sendtext
import time
#https://github.com/ilteoood/SiteAlert-Python/blob/master/SiteAlert.py
#telegram: https://github.com/alexander-akhmetov/python-telegram/blob/master/examples/send_message.py
watcher = MagWatcher(freq = 60)
calculator = KIndexCalculator()
watcher.service()
prev_q=0
while True:
    try:       
        q=calculator.calculate_q_by_ml(watcher.get_data())
        print(q)
        if prev_q!=q and q>2:
            test = telegram_bot_sendtext("probability for aurora: "+ get_probability(q)+"(q="+str(q)+")")            
        prev_q=q
        time.sleep(60)
    except Exception as e:
        print(e)
        time.sleep(5)
# Out:
# init current_ts_utc: 2021-12-21 17:10:20.925938
# init KIndexCalculator
# start
# 0:40:00.006001
# new lines 2279
# 206 Partial Content 86400
# 1
# start
# 0:03:02.186678
# 1
# new lines 112
# 206 Partial Content 6552
# 1
# start
# 0:02:10.361296
# new lines 0
# 206 Partial Content 4680
# 1
# start
# 0:03:10.515781
# new lines 120
# 206 Partial Content 6840
# 1
# start
# 0:02:10.760295
# new lines 0
# 206 Partial Content 4680
# 1
# start
# 0:03:10.913911
# new lines 120
# 206 Partial Content 6840
# 1
# start
# 0:02:11.070862
# new lines 0
# 206 Partial Content 4716
# 1
# start
# 0:03:11.228499
# new lines 120
# 206 Partial Content 6876
# 1
# start
# 0:02:11.413050
# new lines 0
# 206 Partial Content 4716
# 1
# start
# 0:03:11.585226
# new lines 120
# 206 Partial Content 6876
# 1
# start
# 0:02:11.734346
# new lines 0
# 206 Partial Content 4716
# 1
# start
# 0:03:11.896851
# new lines 122
# 206 Partial Content 6876
# 1
# start
# 0:02:10.067043
# new lines 0
# 206 Partial Content 4680
# ...

# %%
from fastai.vision.all import *
from fastbook import *

matplotlib.rc('image', cmap='Greys')
# Out:
# c:\projects\aurora\venv\lib\site-packages\fastbook\__init__.py:19: UserWarning: Missing `graphviz` - please run `conda install fastbook`
#   except ModuleNotFoundError: warn("Missing `graphviz` - please run `conda install fastbook`")
